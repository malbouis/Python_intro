# %% [markdown]
# # Introdução a Python
#
# Esse é um curso de **introdução** a Python, aberto a todas as pessoas que queiram aprender essa linguagem de programação. Não é necessário nenhum conhecimento prévio de Python ou qualquer outra linguagem de programação.
#
# É desejável que a aluna ou o aluno tenham algum conhecimento de Linux, pois utilizaremos computadores com esse sistema operacional, porém não é mandatório. Aos que não têm conhecimento prévio de linux, recomendamos que pesquisem os comandos simples, como listar arquivo em um diretório ou criar um diretório.
#
# A versão de Python utilizada no curso será **Python3**.
#
# ## Organização
#
# Todas as informações importantes serão transmitidas através da nossa página Twiki de [**Introdução a Python**](http://dfnae.fis.uerj.br/twiki/bin/view/DFNAE/IntroPython).
#
# **Professoras do curso**: Clemencia Mora (sala 3024 A) & Helena Malbouisson (sala 3018 A)
#
# ### Ementa:
#
# Abordaremos os seguintes tópicos ao longo do curso:
#
#    1. **Introdução à computação científica com Python**
#       * A computação na Ciência
#       * O que é Python?
#       * Laboratorio: Projeto de introdução
#
#    1. **Introdução à Programação com Python**
#       * Módulos
#       * Variáveis, expressões e declarações
#       * Funções
#       * Lógica booleana, expressões condicionais e recursões
#       * Iteração
#       * Estrutura de Dados:
#          * Strings
#          * Listas
#          * Dicionários
#          * Tuplas
#       * Arquivos
#       * Classes
#       * Criar um módulo
#       * Herança
#       * Laboratorio 1: Projeto de primeiro programa
#
#    1. **Pacotes de Python**
#       * rootpy
#       * Numpy
#       * Scipy
#       * Matplotlib
#       * Laboratorio 2: Projeto de resolução de problema da física
#
#    1. **R**
#       * Laboratorio 3: Analise com R , R para experimentos
#
#    1. **Introdução a Redes Neurais e Machine Learning <font color='red'>(????)</font>**
#
#
# ### Avaliação
#
# A avaliação do curso será feita através de **dois projetos**, que abordarão os tópicos vistos até o momento da realização dos mesmos.
#
# Como forma extra de avaliação, poderemos eventualmente considerar a resolução dos exercícios que serão passados ao longo do curso.
#
#
# ### Preparação
#
# Pedimos que os alunos e alunas criem uma conta no [**github**](https://github.com/), onde armazenarão as suas soluções aos exercícios propostos durante as aulas, assim como os dois projetos do curso.
#
# Nos comunicaremos com os alunos e alunas através do email do curso: **intropython.if.uerj at gmail.com**
#
# A sala 3053F, onde ocorrerão as aulas tem computadores disponíveis e portanto não é necessário trazer laptop.
#
# Quem tem sistema operacional Windows ou MacOS em seus computadores pessoais, recomendamos que instalem o genrenciador de pacotes [**Anaconda**](https://www.anaconda.com/distribution/) (Versão de Python 3.7) e utilizem o programa **Spyder** para editar e rodar seus programas em Python3.
#
#
# ### Bibliografia sugerida
#
# Também disponível na Twiki
#
# * [Think Python 2nd Edition](http://greenteapress.com/thinkpython2/html/index.html)
# * [How to Think Like a Computer Scientist](http://openbookproject.net/thinkcs/python/english3e/)
# * "Learning Python, 5th Edition", Mark Lutz, O'Reilly

# %%
2+2
# Out:
# 4
