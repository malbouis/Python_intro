# %% [markdown]
# <a href="https://colab.research.google.com/github/malbouis/Python_intro/blob/master/aulas_2026-1/Lishep/LISHEP_Python_HMalbouisson_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://indico.cern.ch/event/869979/logo-1145932970.png)
# <center>
#
# **LISHEP SESSÃO A**
#
# Clemencia Mora, Dilson de Jesus Damião, **Helena Malbouisson**
#
# ![](https://www.uerj.br/wp-content/uploads/2018/02/logomarca-uerj.png)
#
# </center>
#
# <br>
#
# Os exemplos dessas aulas são baseados nesse tutorial: [Let's Learn Python](http://www.letslearnpython.com/learn/).
#
# ---
#
#
#
# ![](https://www.python.org/static/img/python-logo@2x.png)
#
# ## Aula 1
#
# ### Que aula é essa?! 🤔
# * Essa aula é sobre a linguagem de programação **Python**.
#
# ### É destinada a que público?
# * Essas aulas foram pensadas principalmente para quem nunca programou ou para quem teve pouco contato com outras linguagens de programação. Mas claro que são abertas a todas e todos que tenham interesse em aprender.
#
# ### O que se espera de vocês ***antes*** das aulas:
# 1. Que não tenham medo do computador (ou com disposição para perder o medo 😉 )
#
# 1. Saber uma outra linguagem de programação é vantagem mas não um requerimento
#
# 1. Que tenham curiosidade
#
# ### O que se espera que aprendam:
# * Escrever um script simples de python e saber onde procurar informação para códigos mais complexos
#
#
# ---
#
# <br>
#
# # Ferramentas populares para Ensino e Aprendizado de Python
#
# * A ferramenta que estamos usando para essas aulas é o [Google Colaboratory](https://colab.research.google.com/).
#
#    * O [Google Colaboratory](https://colab.research.google.com/) é um ambiente no seu navegador que usa a nuvem do Google. É construído em cima do [Jupyter Notebook](https://jupyter.org/) e usa Python como linguagem de programação.
#
#    * Cada arquivo do Google Colaboratory (ou somente Colab) é chamado de um "notebook", ou bloco de notas.
#
#    * Para ter acesso a esse notebook de aula e executar os exemplos que se encontram aqui, você deverá ter (e se não tiver, criar) uma conta Google e copiar esse notebook para o seu Google Drive.
#
# * Outra opção para rodar os exemplos que serão mostrados aqui, é ter python e o jupyter notebook instalados no seu computador.
#    * Para instalar python no seu computador, você pode instalar o gerenciador de pacotes [Anaconda](https://www.anaconda.com/products/individual), que além de instalar Python, instala também vários pacotes úteis além do [***Spyder***](https://www.spyder-ide.org/) Ambiente Integrado de Desenvolvimento e Aprendizado (IDLE, do inglês *Integrated Development and Learning Environment*)
#
# * Existem também ferramentas como o [Trinket](https://trinket.io/), que possibilita rodar scripts de python online (e que tem algumas bibliotecas adicionais que o Colab não tem).
#
# * [**Raspberry pi**](https://www.raspberrypi.org/): micro computador que já vem com python instalado. De baixo custo e ultra portátil.
#    * O Raspberry pi tem **muitos** [projetos legais](https://projects.raspberrypi.org/en/projects) para crianças, adolescentes e iniciantes em geral.
#
# * [Scratch Junior](https://www.scratchjr.org/): aplicativo gratuito para crianças de 5 a 7 anos, voltado para o aprendizado da lógica de programação.
#
# * [Scratch](https://scratch.mit.edu/): site gratuito desenvolvido pelo MIT para crianças a partir de 8 anos desenvolverem seus projetos, voltado para a lógica de programação, com programação em blocos.
#
# * [Blockly Games](https://blockly.games/?lang=pt-br): série de jogos educacionais gratuitos e de código aberto, desenvolvida pelo Google para o ensino da lógica de linguagem de programação através da programação em blocos. Baseado em Java-Script.
#
#
# * Para informações sobre as bibliotecas de Python, tutoriais e programas, visite o site do [Python](http://www.python.org).
#
# <br>
#
# ---
#
# <br>
#
# ## Organização do Curso:
# * **Aula 1**:
#    * Introdução
#    * Matemática com Python
#    * Tipos de dados de Python: inteiros, floats, strings, listas
# * **Aula 2**:
#    * Tipos de dados de Python: Booleanos
#    * Variáveis
#    * Condicionais
#    * Loops
#    * Funções
# * **Aula 3**:
#    * Exemplo didático: Calculando $\pi$
#    * Sobre o projeto de ensino de Python nas escolas públicas

# %% [markdown]
# # Referências:
# * [Python](http://www.python.org)
# * [Let's Learn Python](http://www.letslearnpython.com/learn/)
# * [PyCon North America conference](https://us.pycon.org/2020/)
# * [Pense Python](https://penseallen.github.io/PensePython2e/)
# * [Think Python: How to Think Like a Computer Scientist](https://greenteapress.com/thinkpython2/html/index.html)

# %% [markdown]
# ## O que é Python?
#
# Python é uma **linguagem de programação** de alto nível, orientada a objetos, moderna e de propósito geral.
#
# **Características gerais de Python:**
#
# * **linguagem simples e limpa**: código intuitivo e fácil de ler, sintaxe minimalista de fácil aprendizado, capacidade de manutenção escalável bem com o tamanho dos projetos;
#
# * **linguagem expressiva**: Menos linhas de código, menos bugs, mais fácil de manter.
#
# **Detalhes técnicos:**
#
# * **Digitado dinamicamente**: Não há necessidade de definir o tipo de variáveis, argumentos de função ou tipos de retorno;
#
# * **Gerenciamento automático de memória**: Não é necessário alocar e desalocar explicitamente a memória para variáveis e matrizes de dados. Não há vazamentos de memória (memory leak bugs);
#
# * **interpretado**: Não há necessidade de compilar o código. O interpretador Python lê e executa o código python diretamente.
#
# **Vantagens:**
#
# * A principal vantagem é a facilidade de programação, minimizando o tempo necessário para desenvolver, debugar (procurar por erros no programa) e manter o código;
# * Linguagem bem projetada que incentiva muitas boas práticas de programação:
#
#    * Programação modular e orientada a objetos, bom sistema para empacotamento e reutilização de código. Isso geralmente resulta em código mais transparente, sustentável e livre de bugs;
#
#    * Documentação totalmente integrada com o código;
#
#    * Uma grande biblioteca padrão e uma grande coleção de pacotes complementares;
#
#    * **Muita documentação disponível!**
#
# **Desvantagens:**
#
# * Como o Python é uma linguagem de programação interpretada e dinamicamente digitada, a execução do código python pode ser lenta em comparação com as linguagens de programação compiladas estaticamente, como C e Fortran. Mas na maioria dos casos, Python tem uma excelente performance.

# %% [markdown]
# ## Opções de acesso a Python
#
# Como já mencionado, vamos trabalhar no Google Colab. Qualquer pessoa com um celular/computador e internet, pode rodar facilmente todos os exemplos que faremos aqui. Escolhemos o Google Colab por considerarmos o ambiente mais amigável para quem está somente com celular (apesar do ideal ser um computador) e pela facilidade de não ter que instalar Python no seu sistema operacional. O ponto negativo é que é necessário acesso à internet.
#
# Quem preferir instalar Python no computador/laptop, recomendamos a instalação do gerenciador de pacotes [Anaconda](https://www.anaconda.com/), ou o [PyCharm](https://www.jetbrains.com/pt-br/pycharm/). Mas existem *muitos* ambientes IDE (do inglês, *Integrated Development Environment*, Ambiente Integrado de Desenvolvimento) que reunem ferramentas para o desenvolvimento de programas e aprendizado de Python. Caso não se adapte aos listados acima, você pode procurar outras opções e escolher o seu preferido. Um bom ponto de partida é o site do [Python](http://www.python.org).

# %% [markdown]
# ## O interpretador de Python
#
# De forma pouco formal, podemos dizer que o Python (assim como todas as outras linguagens de programação) é uma maneira de enviar comandos ao computador (que entende a linguagem de máquina). Nós "falamos" (enviamos comandos) através de uma linguagem que sabemos codificar (Python) e o interpretador (de Python) "traduz" os comandos para a linguagem do computador (binária, em 0 e 1) e retorna a resposta em uma linguagem que entendemos. Isso torna o nosso programa **portátil**. O mesmo código fonte escrito em Python, funciona em qualquer computador com Python instalado.
#
# No Google Colab, essa ferramenta que estamos usando aqui, a forma com que acessamos o interpretador é abrindo uma **célula** de ***Código***, indicada como '+ Code' no canto alto da esquerda desse *notebook*. Para rodar o código de Python, clicamos na seta no canto alto à esquerda da célula de código.
#
# Lembre-se que quando digitamos na célula 'Code' do Google Colab e apertamos a seta no canto alto à esquerda da célula do Google Colab, o que está sendo feito é:
#
# * traduzir o que digitamos;
# * falar com o computador;
# * obter uma resposta do computador e enviar de volta para a gente em uma linguagem que compreendemos.

# %% [markdown]
# ## O que é programação?
#
# Todo programa começa com um problema que queremos resolver.
#
# Podemos dizer que programar é uma forma de tornar tarefas complexas em uma sucessão de sub-tarefas simples, de forma que possamos resolver o problema com uma série de instruções básicas, que chamamos de **algoritmo**.
#
# Ou seja, o **conjunto de algoritmos** é a resolução do problema inicial e compõe o **programa**.
#
# Uma vez o programa estabelecido (sucessão de algoritmos a serem executados pelo computador), o interpretador (como por exemplo, Python) fará a tradução para a **linguagem do computador**, que executará os comandos e retornará o resultado encontrado.

# %% [markdown]
# ## Noções básicas de matemática com Python
#
# Vamos começar com exemplos extremamente simples de operações matemáticas e usar Python como uma calculadora.

# %%
22 + 4
# Out:
# 26

# %%
12 - 4
# Out:
# 8

# %%
14 - 9 + 8
# Out:
# 13

# %% [markdown]
# Em programação, chamamos os símbolos matemáticos de **operadores**.

# %%
6*5
# Out:
# 30

# %%
28/4
# Out:
# 7.0

# %%
28 * 5 / 6
# Out:
# 23.333333333333332

# %% [markdown]
# Operadores |  símbolo
# --- | ---
# adição | +
# subtração | -
# multiplicação | *
# divisão | /

# %% [markdown]
# ## Floats e inteiros
#
# Em Python (e em muitas outras linguagens de programação) um número decimal é chamado de **float**.
#
# Quando fazemos alguma operação que tem como resultado um número decimal, Python nos retorna um valor do **tipo float**.
#
# Assim como quando temos um número inteiro como resultado, o valor é do **tipo inteiro**.
#
# Abaixo, podemos ver exemplos de floats e inteiros.

# %%
# Float:
10/3
# Out:
# 3.3333333333333335

# %%
#inteiro:
int(9/3)
# Out:
# 3

# %% [markdown]
# Existe uma função *built-in* de Python, que arredonda os **floats**, para o caso em que a gente queira somente inteiros. Essa função é chamada de `round()`.

# %%
round(10/3)
# Out:
# 3

# %% [markdown]
# ## O que vimos até agora
#
#
# * Python é uma **linguagem de programação** que traduz o que "dizemos" para **linguagem de máquina** (computador), para que o computador possa **executar** os comandos que estabelecemos (algoritmos);
#
# * Um **programa** é um conjunto de **algoritmos** que visam **solucionar um problema**;
#
# * Quando dizemos que o Python **retorna** algo, estamos falando das respostas que o Python nos fornece. Quando você digita algo no `célula` do Google Colab e pressiona a `seta`, está fazendo uma pergunta ao Python. Então o Python devolve, ou retorna, uma resposta para você;
#
# * Também usamos a palavra **expressão** - você ouvirá muito mais à medida que prosseguir com o estudo sobre Python. Até agora, as expressões que vimos foram problemas de matemática. Mas expressões podem ser muito mais - também vamos ver algumas expressões que usam palavras e outros tipos de símbolos.
#
# * Existem **tipos** de dados de Python, associados a valores. Os que vimos até agora foram **floats** e **inteiros**.

# %% [markdown]
# ## Operadores de comparação
#
# Existem situações em que queremos comparar valores ou expressões. Para tal, existem os **operadores de comparação**.
#
# Operador | Significado
# ---|---
# == | Igual a
# != | Diferente de
# < | Menor que
# > | Maior que
# <= | Menor ou igual a
# >= | Maior ou igual a
#
# Mais para a frente, veremos exemplos de como programar esses operadores de comparação. Por agora, vamos entender como eles funcionam.
#
# Vamos ver o que acontece quando executamos as expressões abaixo. Tente antecipar o resultado antes de executar a célula.

# %%
5 < 4 + 3
# Out:
# True

# %%
12 + 1 >= 12
# Out:
# True

# %%
16 * 2 == 32
# Out:
# True

# %%
16 != 16
# Out:
# False

# %%
5 >= 6
# Out:
# False

# %% [markdown]
# * A primeira observação que você provavelmente notou é que as expressões retornadas não são números. Faz sentido, já que estamos comparando duas quantidades e nos perguntando se as expressões são verdadeiras (True) ou falsas (False). Esses resultados representam também um **tipo** de valor de Python, que é chamado de **Boolean**;
#
# * Outro ponto importante é o que chamamos de **ordem da operação**. As expressões simples, como **adição ou multiplicação** são sempre executadas **antes da comparação**.

# %% [markdown]
# ## Strings
#
# O tipo de dados de Python que lida com caracteres são as `strings`.
#
# A forma de escrever strings, ou **sintaxe**, em Python é colocar os caracteres entre aspas:

# %%
'banana'
# Out:
# 'banana'

# %% [markdown]
# ## Concatenação de strings

# %%
variavel = "esse é um exemplo de string"
variavel_2 = "e de concatenação de string"
variavel_final = variavel + " " + variavel_2

print(variavel)
print(variavel_2)
print(variavel_final)
# Out:
# esse é um exemplo de string
# e de concatenação de string
# esse é um exemplo de string e de concatenação de string

# %% [markdown]
# A concatenação é um exemplo de **operação** com strings.
# Vejamos um outro exemplo de **concatenação**:

# %%
oi = "hello! "*3
print(oi)
# Out:
# hello! hello! hello!

# %% [markdown]
# ## Indexação de Strings
#
# Os caracteres das strings podem ser acessados através da **indexação** da string.
#
# As strings podem ser indexadas (subscritas), com o primeiro caractere como índice 0.

# %%
palavra = "Python"
palavra[0]
# Out:
# 'P'

# %%
palavra[4]
# Out:
# 'o'

# %%
palavra[-1] #último caracter
# Out:
# 'n'

# %%
palavra[-2] #penúltimo caracter
# Out:
# 'o'

# %%
palavra[2:5] #caracteres da posição 2 até a posição 4
# Out:
# 'tho'

# %% [markdown]
# Para facilitar o entendimento de como funciona os índices
# ```
# +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#    0   1   2   3   4   5
#   -6  -5  -4  -3  -2  -1
#
# ```
#
# **Atenção:**
#
# As strings do Python não podem ser alteradas — uma string é **imutável**. Se você precisar de uma string diferente, deverá criar uma nova.

# %%
palavra[0] = "J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-988f1919f181> in <module>()
# ----> 1 palavra[0] = "J"
#
# TypeError: 'str' object does not support item assignment

# %%
"J" + palavra[1:]
# Out:
# 'Jython'

# %%
palavra[:2] + "py"
# Out:
# 'Pypy'

# %% [markdown]
# Se precisar saber o comprimento de uma **string**, utilize a função `len()`

# %%
tamanho = "tamanho da string. Os espaços também contam como string."
len(tamanho)
# Out:
# 56

# %% [markdown]
# ## Listas: Uma coleção de objetos
#
# Vamos adicionar mais um **tipo** de dados de Python aos que já vimos até agora: as **listas**.
#
# Uma lista é uma coleção de objetos e a sintaxe consiste em dois colchetes que contêm os objetos, que por sua vez são separados por vígulas (que chamamos de **delimitadores**):

# %%
minha_lista = ['banana', 15.4, 8]
type(minha_lista)
# Out:
# list

# %% [markdown]
# Os objetos de uma lista são chamados de **elementos** ou **itens**.
#
# Os tipos de dados de Python que vimos até agora são:
#
# Tipo |  exemplo
# --- | ---
# string | 'banana'
# float | 15.4
# int  | 8
# list | ['banana', 15.4, 8]

# %% [markdown]
# As listas são **indexadas**, assim como as **strings**.
#
# Ou seja, se considerarmos o exemplo `minha_lista` acima, e quisermos acessar seus objetos, devemos considerar os índices:
#
# ```
# +--------+----------+----+---+
#  lista  | ['banana', 15.4, 8]
# índices |      0   ,   1 , 2
# +--------+----------+----+---+
#
# ```
#
# Se quisermos por exemplo acessar o objeto de índice 0:

# %%
minha_lista[0]
# Out:
# 'banana'

# %%
minha_lista[1]
# Out:
# 15.4

# %%
minha_lista[2]
# Out:
# 8

# %%
minha_lista[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-0be4e7d8c57f> in <module>()
# ----> 1 minha_lista[3]
#
# IndexError: list index out of range

# %% [markdown]
# O que acontece quando tentamos acessar o índice 3 de `minha_lista`, é que o interpretador lança uma mensagem de erro. Isso porque a  `minha_lista` só vai até o índice 3.
#
# Podemos determinar o tamanho de uma lista com a função do Python `len()`:

# %%
len(minha_lista)
# Out:
# 3

# %% [markdown]
# As listas são **mutáveis**, ou seja, podemos modificar os valores dos seus elementos:

# %%
print(minha_lista[2])
minha_lista[2] = 9
print(minha_lista)
# Out:
# 8
# ['banana', 15.4, 9]

# %%
minha_lista.append(22.8)
print(minha_lista)
# Out:
# ['banana', 15.4, 9, 22.8]

# %% [markdown]
# As listas são um tipo muito usado em Python e têm muitos métodos (ou funções) associados. Para aprender sobre outros métodos associados a listas, veja a documentação de Python [nesse link](https://docs.python.org/3/tutorial/datastructures.html) e também [nesse outro link](https://docs.python.org/3/tutorial/introduction.html#lists).
#
#
#
# ---

# %% [markdown]
# # Próxima aula
#
# * Tipos de dados de Python: Booleanos
# * Variáveis
# * Condicionais
# * Loops
# * Funções

# %% [markdown]
# #Exercício
#
# Copie esse notebook e rode todas as células. Modifique alguns valores e verifique se obteve o que esperava ao modificar a célula.
