# %% [markdown]
# <a href="https://colab.research.google.com/github/malbouis/Python_intro/blob/master/aulas_2021-1/aula0_introducao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução a Python
#
# Esse é um curso de **introdução** a Python, aberto a todas as pessoas que queiram aprender essa linguagem de programação. Não é necessário nenhum conhecimento prévio de Python ou qualquer outra linguagem de programação.
#
# A versão de Python utilizada no curso será **Python3**.
#
# ## Organização
#
# * Todas as informações importantes serão transmitidas através da nossa página Twiki de [**Introdução a Python**](http://dfnae.fis.uerj.br/twiki/bin/view/DFNAE/IntroPython) e também através da [**sala de aula**](https://ava.pr1.uerj.br/course/view.php?id=1315) do Ambiente Virtual de Aprendizagem (AVA);
#
#    * É possível se cadastrar no AVA com seu ID único (alunos UERJ);
#    * Alunos externos, favor entrar em contato com a secretaria do PPGF (ppgf.if -at- gmail.com);
#    * Sempre é possível entrar em contato conosco através do email intropython.if.uerj -at- gmail.com
#
#
#
# **Professoras do curso**: Clemencia Mora & Helena Malbouisson
#    * **Aluno de Estágio Docente**: Gabriel Moreira da Silva Campos
#
# ### Ementa:
#
# Abordaremos os seguintes tópicos ao longo do curso:
#
#    1. **Introdução à computação científica com Python**
#       * A computação na Ciência
#       * O que é Python?
#       * Laboratorio: Projeto de introdução
#
#    1. **Introdução à Programação com Python**
#       * Módulos
#       * Variáveis, expressões e declarações
#       * Funções
#       * Lógica booleana, expressões condicionais e recursões
#       * Iteração
#       * Estrutura de Dados:
#          * Strings
#          * Listas
#          * Dicionários
#          * Tuplas
#       * Arquivos
#       * Classes
#       * Criar um módulo
#       * Herança
#       * Laboratorio 1: Projeto de primeiro programa
#
#    1. **Pacotes de Python**
#       * rootpy
#       * Numpy
#       * Scipy
#       * Matplotlib
#       * Laboratorio 2: Projeto de resolução de problema da física
#
#    1. **JIT e decoradores** (a confirmar)
#       * como utilizar pacotes pré-compilados como o numba.
#
#    1. **Introdução a Redes Neurais e Machine Learning (tópico extra)**
#
#
# ### Avaliação
#
# A avaliação do curso será feita através de **dois projetos**, que abordarão os tópicos vistos até o momento da realização dos mesmos.
#
# Datas aproximadas de apresentação dos projetos:
# * Projeto 1: 08/10/2021
# * Projeto 2: 26/11/2021
#
# Como forma extra de avaliação, poderemos eventualmente considerar a resolução dos exercícios que serão passados ao longo do curso.
#
#
# ### Preparação
#
# Pedimos que os alunos e alunas criem uma conta no [**github**](https://github.com/), onde armazenarão as suas soluções dos exercícios propostos durante as aulas, assim como os projetos do curso.
#
# Nos comunicaremos com os alunos e alunas através do email do curso: **intropython.if.uerj at gmail.com** ou do Fórum do AVA.
#
#
# Nesse Período Acadêmico Especial (PAE), teremos nossas aulas adaptadas ao Google Colab.
#
# * O [Google Colaboratory](https://colab.research.google.com/) é um ambiente no seu navegador que usa a nuvem do Google. É construído em cima do [Jupyter Notebook](https://jupyter.org/) e usa Python como linguagem de programação.
#
# * Cada arquivo do Google Colaboratory (ou somente Colab) é chamado de um "notebook", ou bloco de notas.
#
# * Para ter acesso a esse notebook e executar os exemplos que se encontram aqui, você deverá ter (e se não tiver, criar) uma conta Google e copiar esse notebook para o seu Google Drive.
#
# * É possível salvar um notebook no github.
#
# * [Vídeo explicativo](https://www.youtube.com/watch?v=gCZA95VIjxg&t=181s) das funcionalidades mais básicas do Google Colab.
#
# ### Aulas
#
# As aulas serão **síncronas**, oferecidas através da plataforma Zoom (link enviado por email).
#    * Os *notebooks* com as soluções aos exercícios propostos nas aulas deverão ser armazenados no repositório github que vocês criarão para o curso. Acesse [esse link do AVA](https://ava.pr1.uerj.br/mod/assign/view.php?id=81109) para enviar o link do seu repositório github.
#       * Os alunos externos sem acesso ao AVA podem enviar para o email do curso.
#
# * **Todas as aulas serão gravadas**. Assim, quem não tiver disponibilidade no horário das aulas síncronas poderão ter acesso à gravação das aulas.
#
# * **Horário proposto para as aulas síncronas:**
#    * Terça-feira: 14h20 às 16h00
#    * Quinta-feira: 14h20 às 18h00
#    * Monitoria: Sexta-feira 10h30 às 12h00.
#
# ### Bibliografia sugerida
#
#
# * [Think Python 2nd Edition](http://greenteapress.com/thinkpython2/html/index.html)
# * [Pense em Python](https://penseallen.github.io/PensePython2e/)
# * [How to Think Like a Computer Scientist](http://openbookproject.net/thinkcs/python/english3e/)
# * "Learning Python, 5th Edition", Mark Lutz, O'Reilly
